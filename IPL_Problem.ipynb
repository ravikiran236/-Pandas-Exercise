# %%
import pandas as pd

# %% [markdown]
# ### setting currenct working directory

# %%
import os
os.chdir("B:/Amith Mentorship")

# %%
ipl = pd.read_csv("iplfinal.csv", sep='|')

# %%
ipl.head()  ## first 6 rows
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes
# 0     c Rayudu b Watson    15     18      1      1
# 1        lbw b D Chahar     0      2      0      0
# 2   c Mark Wood b Tahir    40     29      4      1
# 3  c Harbhajan b Watson    43     29      6      1
# 4               not out    22     20      2      0

# %%
#1 what is the maximum score of IPL 2018 and who scored it?
print(ipl[['batsman_name', 'runs']][ipl.runs == ipl.runs.max()])
# Out:
#           batsman_name  runs
# 680  Rishabh Pant (wk)   128

# %%
#2 how many centuries were hit in IPL 2018?
ipl[ipl['runs'] >=100].count()['runs']
# Out:
# 5

# %%
# creating and adding strike rate column to the data frame
ipl['strike rate'] = (ipl['runs']/ ipl['balls'])*100

# %%
# checking whether the strike rate column is added to data frame or not
ipl.head()
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes  strike rate
# 0     c Rayudu b Watson    15     18      1      1    83.333333
# 1        lbw b D Chahar     0      2      0      0     0.000000
# 2   c Mark Wood b Tahir    40     29      4      1   137.931034
# 3  c Harbhajan b Watson    43     29      6      1   148.275862
# 4               not out    22     20      2      0   110.000000

# %%
#3 list down the century makers, their scores and their strike rates
ipl[['batsman_name', 'runs', 'strike rate']][ipl['runs']>= 100]
# Out:
#           batsman_name  runs  strike rate
# 274        Chris Gayle   104   165.079365
# 285       Shane Watson   106   185.964912
# 680  Rishabh Pant (wk)   128   203.174603
# 739      Ambati Rayudu   100   161.290323
# 959       Shane Watson   117   205.263158

# %%
#6 what are the total number of duck dismissals?
ipl[ipl['runs'] ==0].count()['runs']
# Out:
# 103

# %%
# Creating Boundary Percentage field
ipl['boundary %'] = (((4*ipl['fours'])+(6*ipl['sixes']))/ipl['runs'])*100

# %%
# Checking whether Boundary % field is created or not
ipl.head()
# Out:
#                                    match_description  match_date  \
# 0  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 1  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 2  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 3  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
# 4  Mumbai Indians vs Chennai Super Kings, 1st Mat...  2018-04-07
#
#          match_venue match_location                      match_result  \
# 0  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 1  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 2  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 3  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
# 4  Wankhede Stadium,         Mumbai  Chennai Super Kings won by 1 wkt
#
#                 team_name innings_order       batsman_name  \
# 0  Mumbai Indians Innings     innings_1   Rohit Sharma (c)
# 1  Mumbai Indians Innings     innings_1         Evin Lewis
# 2  Mumbai Indians Innings     innings_1  Ishan Kishan (wk)
# 3  Mumbai Indians Innings     innings_1   Suryakumar Yadav
# 4  Mumbai Indians Innings     innings_1      Hardik Pandya
#
#          dismissal_mode  runs  balls  fours  sixes  strike rate  boundary %
# 0     c Rayudu b Watson    15     18      1      1    83.333333   66.666667
# 1        lbw b D Chahar     0      2      0      0     0.000000         NaN
# 2   c Mark Wood b Tahir    40     29      4      1   137.931034   55.000000
# 3  c Harbhajan b Watson    43     29      6      1   148.275862   69.767442
# 4               not out    22     20      2      0   110.000000   36.363636

# %%
# lit top 5 players by contribution of boundaries to total scores
ipl.nlargest(5,{'boundary %'},keep = 'first')
# Out:
#                                      match_description  match_date  \
# 32   Kolkata Knight Riders vs Royal Challengers Ban...  2018-04-08
# 62   Kolkata Knight Riders vs Royal Challengers Ban...  2018-04-08
# 78   Sunrisers Hyderabad vs Rajasthan Royals, 4th M...  2018-04-09
# 92   Chennai Super Kings vs Kolkata Knight Riders, ...  2018-04-10
# 143  Royal Challengers Bangalore vs Kings XI Punjab...  2018-04-13
#
#                              match_venue match_location  \
# 32                         Eden Gardens,        Kolkata
# 62                         Eden Gardens,        Kolkata
# 78   Rajiv Gandhi International Stadium,      Hyderabad
# 92               MA Chidambaram Stadium,        Chennai
# 143               M.Chinnaswamy Stadium,      Bengaluru
#
#                                   match_result  \
# 32         Kolkata Knight Riders won by 4 wkts
# 62         Kolkata Knight Riders won by 4 wkts
# 78           Sunrisers Hyderabad won by 9 wkts
# 92           Chennai Super Kings won by 5 wkts
# 143  Royal Challengers Bangalore won by 4 wkts
#
#                                team_name innings_order          batsman_name  \
# 32   Royal Challengers Bangalore Innings     innings_1  Quinton de Kock (wk)
# 62   Royal Challengers Bangalore Innings     innings_1  Quinton de Kock (wk)
# 78              Rajasthan Royals Innings     innings_1          D Arcy Short
# 92         Kolkata Knight Riders Innings     innings_1          Sunil Narine
# 143              Kings XI Punjab Innings     innings_1          Yuvraj Singh
#
#              dismissal_mode  runs  balls  fours  sixes  strike rate  \
# 32   c Vinay Kumar b Chawla     4      4      1      0        100.0
# 62   c Vinay Kumar b Chawla     4      4      1      0        100.0
# 78     run out (Williamson)     4      4      1      0        100.0
# 92      c Raina b Harbhajan    12      4      0      2        300.0
# 143                 b Umesh     4      4      1      0        100.0
#
#      boundary %
# 32        100.0
# 62        100.0
# 78        100.0
# 92        100.0
# 143       100.0
